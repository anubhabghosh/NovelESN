# %%
import pandas as pd
import numpy as np
import os

# %%
def get_params_per_config(texts):
    
    params_count_arr = []
    for line in texts:
        if 'params' in line.lower():
            p = line.split(":")[-1]
            params_count_arr.append(p)
    ms_count_arr = np.array(params_count_arr).astype(np.int)
    #print(params_count_arr)
    return ms_count_arr

def get_num_configs(texts):
    
    num_configs = 0
    for line in texts:
        if 'config:' in line.lower():
            num_configs += 1
        
    #print("Number of configurations:{}".format(num_configs))
    return num_configs
    
def get_telapsed_per_config(texts):
    
    config_count = 0
    t_arr = []
    for line in texts:
        if 'config:' in line.lower():
            #print(line)
            config_count += 1
        elif 'time elapsed measured' in line.lower():
            t = line.strip().split(":")[1]
            #print("Time for Config {}: {} s \n".format(config_count, t))
            t_arr.append(t)

    t_arr = np.array(t_arr).astype(np.float)
    return t_arr

# %%
def get_best_osize_df(df, group_by, sort_field, n_top):
    df1 = df.groupby(group_by).apply(
    lambda x: x.sort_values(by=sort_field,
                            ascending=True, 
                            ignore_index=True).head(n_top)
    )
    return df1

# %%
def get_model_gsresults(folder, model_type, solar_cycle, group_by=None, n_top=None):
    
    # Get the logfile name
    logfile = "{}_gs_cycle_{}_logs.txt".format(model_type, solar_cycle)
    
    # Get the .json file name
    jsonfile = "gsresults_{}_cycle{}.json".format(model_type, solar_cycle)
    
    # Get the full file path
    logfile_path = os.path.join(folder, logfile)
    jsonfile_path = os.path.join(folder, jsonfile)
    
    # Check if the file is present or not
    assert os.path.exists(logfile_path) == True, print("Log file not found!!")
    assert os.path.exists(jsonfile_path) == True, print("Grid search related Json file not found!!")
    
    # Extract the dataframe
    df = pd.read_json(jsonfile_path)
    
    # Get the logfile lines
    with open(logfile_path, 'r') as f:
        texts = f.readlines()
    
    t_arr = get_telapsed_per_config(texts) # get the time elapsed as an array per config
    params_count_arr = get_params_per_config(texts) # get the no. of params per config
    
    # Add the columns from the logfile
    df['Time_Elapsed'] = t_arr
    df['Num_Params'] = params_count_arr
    
    # Get the dataframe based on best val.set performance grouped by output_size
    df_by_osize = get_best_osize_df(df, group_by, 'Validation_Error', n_top)
    
    return df, df_by_osize

# %%
df_gru, df_gru_by_osize = get_model_gsresults(folder='./param_selection/solar_cycle_22_val_modified/',
                                              model_type='gru',
                                              solar_cycle=22,
                                              group_by='output_size',
                                              n_top=2)

# %%
# Print the dataframe
df_gru
# Out:
#     input_size  output_size  n_hidden  n_layers  num_directions model_type  \
# 0            1            1        20         2               1        gru
# 1            1            1        20         2               1        gru
# 2            1            5        20         2               1        gru
# 3            1            5        20         2               1        gru
# 4            1           10        20         2               1        gru
# 5            1           10        20         2               1        gru
# 6            1            1        30         2               1        gru
# 7            1            1        30         2               1        gru
# 8            1            5        30         2               1        gru
# 9            1            5        30         2               1        gru
# 10           1           10        30         2               1        gru
# 11           1           10        30         2               1        gru
# 12           1            1        40         2               1        gru
# 13           1            1        40         2               1        gru
# 14           1            5        40         2               1        gru
# 15           1            5        40         2               1        gru
# 16           1           10        40         2               1        gru
# 17           1           10        40         2               1        gru
# 18           1            1        50         2               1        gru
# 19           1            1        50         2               1        gru
# 20           1            5        50         2               1        gru
# 21           1            5        50         2               1        gru
# 22           1           10        50         2               1        gru
# 23           1           10        50         2               1        gru
# 24           1            1        60         2               1        gru
# 25           1            1        60         2               1        gru
# 26           1            5        60         2               1        gru
# 27           1            5        60         2               1        gru
# 28           1           10        60         2               1        gru
# 29           1           10        60         2               1        gru
#
#     batch_first     lr device  num_epochs  Validation_Error  Training_Error  \
# 0          True  0.001    cpu        4000          0.018680        0.000082
# 1          True  0.001    cpu        5000          0.022987        0.000081
# 2          True  0.001    cpu        4000          0.026470        0.000444
# 3          True  0.001    cpu        5000          0.034520        0.000433
# 4          True  0.001    cpu        4000          0.062637        0.000912
# 5          True  0.001    cpu        5000          0.066112        0.000942
# 6          True  0.001    cpu        4000          0.036004        0.000081
# 7          True  0.001    cpu        5000          0.037216        0.000082
# 8          True  0.001    cpu        4000          0.032227        0.000416
# 9          True  0.001    cpu        5000          0.034582        0.000465
# 10         True  0.001    cpu        4000          0.070194        0.000846
# 11         True  0.001    cpu        5000          0.043310        0.000791
# 12         True  0.001    cpu        4000          0.030330        0.000081
# 13         True  0.001    cpu        5000          3.128426        0.000084
# 14         True  0.001    cpu        4000          0.054693        0.000444
# 15         True  0.001    cpu        5000          0.032308        0.000410
# 16         True  0.001    cpu        4000          0.025544        0.000702
# 17         True  0.001    cpu        5000          0.084801        0.000590
# 18         True  0.001    cpu        4000          0.030123        0.000082
# 19         True  0.001    cpu        5000          0.022609        0.000081
# 20         True  0.001    cpu        4000          0.040093        0.000440
# 21         True  0.001    cpu        5000          0.045319        0.000335
# 22         True  0.001    cpu        4000          0.137588        0.000594
# 23         True  0.001    cpu        5000          0.102932        0.000363
# 24         True  0.001    cpu        4000          0.022553        0.000081
# 25         True  0.001    cpu        5000          0.040704        0.000081
# 26         True  0.001    cpu        4000          0.046784        0.000420
# 27         True  0.001    cpu        5000          0.034250        0.000375
# 28         True  0.001    cpu        4000          0.083968        0.000606
# 29         True  0.001    cpu        5000          0.104544        0.000306
#
#     Time_Elapsed  Num_Params
# 0    3260.273872        3921
# 1    4204.892673        3921
# 2     821.297525        4005
# 3    1064.625585        4005
# 4     483.232461        4110
# 5     574.097484        4110
# 6    3535.251051        8581
# 7    4465.828382        8581
# 8    1127.595065        8705
# 9    1412.693537        8705
# 10    484.367963        8860
# 11    606.797430        8860
# 12   3736.768240       15041
# 13   4246.978849       15041
# 14   1091.121697       15205
# 15   1362.270253       15205
# 16    478.019712       15410
# 17    595.076933       15410
# 18   3559.365549       23301
# 19   4449.046410       23301
# 20   1128.050331       23505
# 21   1408.340041       23505
# 22    515.883860       23760
# 23    646.895201       23760
# 24   3716.183661       33361
# 25   4655.923728       33361
# 26   1076.584123       33605
# 27   1345.066950       33605
# 28    779.975303       33910
# 29    975.124263       33910

# %%
# Print the dataframe with best entries
df_gru_by_osize
# Out:
#                input_size  output_size  n_hidden  n_layers  num_directions  \
# output_size
# 1           0           1            1        20         2               1
#             1           1            1        60         2               1
# 5           0           1            5        20         2               1
#             1           1            5        30         2               1
# 10          0           1           10        40         2               1
#             1           1           10        30         2               1
#
#               model_type  batch_first     lr device  num_epochs  \
# output_size
# 1           0        gru         True  0.001    cpu        4000
#             1        gru         True  0.001    cpu        4000
# 5           0        gru         True  0.001    cpu        4000
#             1        gru         True  0.001    cpu        4000
# 10          0        gru         True  0.001    cpu        4000
#             1        gru         True  0.001    cpu        5000
#
#                Validation_Error  Training_Error  Time_Elapsed  Num_Params
# output_size
# 1           0          0.018680        0.000082   3260.273872        3921
#             1          0.022553        0.000081   3716.183661       33361
# 5           0          0.026470        0.000444    821.297525        4005
#             1          0.032227        0.000416   1127.595065        8705
# 10          0          0.025544        0.000702    478.019712       15410
#             1          0.043310        0.000791    606.797430        8860

# %%
print(len(df_gru_by_osize))
df_gru_by_osize.iloc[2].to_dict()
# Out:
# 6
# {'input_size': 1,
#  'output_size': 5,
#  'n_hidden': 20,
#  'n_layers': 2,
#  'num_directions': 1,
#  'model_type': 'gru',
#  'batch_first': True,
#  'lr': 0.001,
#  'device': 'cpu',
#  'num_epochs': 4000,
#  'Validation_Error': 0.026469580829143004,
#  'Training_Error': 0.000444386940216,
#  'Time_Elapsed': 821.2975248359144,
#  'Num_Params': 4005}

# %%
df_gru_by_osize.sort_values(by='Validation_Error',
                            ascending=True, 
                            ignore_index=True)
# Out:
#    input_size  output_size  n_hidden  n_layers  num_directions model_type  \
# 0           1            1        20         2               1        gru
# 1           1            1        60         2               1        gru
# 2           1           10        40         2               1        gru
# 3           1            5        20         2               1        gru
# 4           1            5        30         2               1        gru
# 5           1           10        30         2               1        gru
#
#    batch_first     lr device  num_epochs  Validation_Error  Training_Error  \
# 0         True  0.001    cpu        4000          0.018680        0.000082
# 1         True  0.001    cpu        4000          0.022553        0.000081
# 2         True  0.001    cpu        4000          0.025544        0.000702
# 3         True  0.001    cpu        4000          0.026470        0.000444
# 4         True  0.001    cpu        4000          0.032227        0.000416
# 5         True  0.001    cpu        5000          0.043310        0.000791
#
#    Time_Elapsed  Num_Params
# 0   3260.273872        3921
# 1   3716.183661       33361
# 2    478.019712       15410
# 3    821.297525        4005
# 4   1127.595065        8705
# 5    606.797430        8860

# %%
df_rnn, df_rnn_by_osize = get_model_gsresults(folder='./param_selection/solar_cycle_22_val_modified/',
                                              model_type='rnn',
                                              solar_cycle=22,
                                              group_by='output_size',
                                              n_top=2)

# %%
df_rnn
# Out:
#     input_size  output_size  n_hidden  n_layers  num_directions model_type  \
# 0            1            1        20         2               1        rnn
# 1            1            1        20         2               1        rnn
# 2            1            5        20         2               1        rnn
# 3            1            5        20         2               1        rnn
# 4            1           10        20         2               1        rnn
# 5            1           10        20         2               1        rnn
# 6            1            1        30         2               1        rnn
# 7            1            1        30         2               1        rnn
# 8            1            5        30         2               1        rnn
# 9            1            5        30         2               1        rnn
# 10           1           10        30         2               1        rnn
# 11           1           10        30         2               1        rnn
# 12           1            1        40         2               1        rnn
# 13           1            1        40         2               1        rnn
# 14           1            5        40         2               1        rnn
# 15           1            5        40         2               1        rnn
# 16           1           10        40         2               1        rnn
# 17           1           10        40         2               1        rnn
# 18           1            1        50         2               1        rnn
# 19           1            1        50         2               1        rnn
# 20           1            5        50         2               1        rnn
# 21           1            5        50         2               1        rnn
# 22           1           10        50         2               1        rnn
# 23           1           10        50         2               1        rnn
# 24           1            1        60         2               1        rnn
# 25           1            1        60         2               1        rnn
# 26           1            5        60         2               1        rnn
# 27           1            5        60         2               1        rnn
# 28           1           10        60         2               1        rnn
# 29           1           10        60         2               1        rnn
#
#     batch_first     lr device  num_epochs  Validation_Error  Training_Error  \
# 0          True  0.001    cpu        4000          0.080716        0.000091
# 1          True  0.001    cpu        5000          0.041096        0.000083
# 2          True  0.001    cpu        4000          0.045094        0.000448
# 3          True  0.001    cpu        5000          0.045219        0.000393
# 4          True  0.001    cpu        4000          0.077390        0.001024
# 5          True  0.001    cpu        5000          0.077685        0.001109
# 6          True  0.001    cpu        4000          0.031070        0.000083
# 7          True  0.001    cpu        5000          0.023744        0.000082
# 8          True  0.001    cpu        4000          0.063914        0.000416
# 9          True  0.001    cpu        5000          0.035451        0.000410
# 10         True  0.001    cpu        4000          0.076926        0.001114
# 11         True  0.001    cpu        5000          1.902917        0.000911
# 12         True  0.001    cpu        4000          0.039476        0.000082
# 13         True  0.001    cpu        5000          0.040471        0.000082
# 14         True  0.001    cpu        4000          0.045213        0.000388
# 15         True  0.001    cpu        5000          0.065485        0.000368
# 16         True  0.001    cpu        4000          0.073215        0.000968
# 17         True  0.001    cpu        5000          0.048315        0.001004
# 18         True  0.001    cpu        4000          0.033809        0.000081
# 19         True  0.001    cpu        5000          0.040059        0.000086
# 20         True  0.001    cpu        4000          0.033879        0.000389
# 21         True  0.001    cpu        5000          0.070474        0.000375
# 22         True  0.001    cpu        4000          0.089120        0.000862
# 23         True  0.001    cpu        5000          0.078362        0.000700
# 24         True  0.001    cpu        4000          0.533473        0.000140
# 25         True  0.001    cpu        5000          0.182365        0.000170
# 26         True  0.001    cpu        4000          0.041726        0.000390
# 27         True  0.001    cpu        5000          0.028442        0.000351
# 28         True  0.001    cpu        4000          0.075776        0.000812
# 29         True  0.001    cpu        5000          0.116752        0.000508
#
#     Time_Elapsed  Num_Params
# 0    1393.552061        1321
# 1    1752.772146        1321
# 2     361.850958        1405
# 3     452.952010        1405
# 4     234.114917        1510
# 5     290.099715        1510
# 6    1452.807329        2881
# 7    1833.972837        2881
# 8     636.986645        3005
# 9     796.896372        3005
# 10    231.576847        3160
# 11    292.573826        3160
# 12   1509.852701        5041
# 13   1832.731675        5041
# 14    606.759593        5205
# 15    758.967603        5205
# 16    240.416127        5410
# 17    299.869923        5410
# 18   1534.421270        7801
# 19   1932.190558        7801
# 20    603.217539        8005
# 21    757.854294        8005
# 22    251.731962        8260
# 23    314.649908        8260
# 24   1712.117079       11161
# 25   2028.510642       11161
# 26    549.738810       11405
# 27    688.853066       11405
# 28    471.958182       11710
# 29    589.303785       11710

# %%
df_rnn_by_osize
# Out:
#                input_size  output_size  n_hidden  n_layers  num_directions  \
# output_size
# 1           0           1            1        30         2               1
#             1           1            1        30         2               1
# 5           0           1            5        60         2               1
#             1           1            5        50         2               1
# 10          0           1           10        40         2               1
#             1           1           10        40         2               1
#
#               model_type  batch_first     lr device  num_epochs  \
# output_size
# 1           0        rnn         True  0.001    cpu        5000
#             1        rnn         True  0.001    cpu        4000
# 5           0        rnn         True  0.001    cpu        5000
#             1        rnn         True  0.001    cpu        4000
# 10          0        rnn         True  0.001    cpu        5000
#             1        rnn         True  0.001    cpu        4000
#
#                Validation_Error  Training_Error  Time_Elapsed  Num_Params
# output_size
# 1           0          0.023744        0.000082   1833.972837        2881
#             1          0.031070        0.000083   1452.807329        2881
# 5           0          0.028442        0.000351    688.853066       11405
#             1          0.033879        0.000389    603.217539        8005
# 10          0          0.048315        0.001004    299.869923        5410
#             1          0.073215        0.000968    240.416127        5410

# %%
df_rnn_by_osize.sort_values(by='Validation_Error',
                            ascending=True, 
                            ignore_index=True)
# Out:
#    input_size  output_size  n_hidden  n_layers  num_directions model_type  \
# 0           1            1        30         2               1        rnn
# 1           1            5        60         2               1        rnn
# 2           1            1        30         2               1        rnn
# 3           1            5        50         2               1        rnn
# 4           1           10        40         2               1        rnn
# 5           1           10        40         2               1        rnn
#
#    batch_first     lr device  num_epochs  Validation_Error  Training_Error  \
# 0         True  0.001    cpu        5000          0.023744        0.000082
# 1         True  0.001    cpu        5000          0.028442        0.000351
# 2         True  0.001    cpu        4000          0.031070        0.000083
# 3         True  0.001    cpu        4000          0.033879        0.000389
# 4         True  0.001    cpu        5000          0.048315        0.001004
# 5         True  0.001    cpu        4000          0.073215        0.000968
#
#    Time_Elapsed  Num_Params
# 0   1833.972837        2881
# 1    688.853066       11405
# 2   1452.807329        2881
# 3    603.217539        8005
# 4    299.869923        5410
# 5    240.416127        5410

# %%
df_lstm, df_lstm_by_osize = get_model_gsresults(folder='./param_selection/solar_cycle_22_val_modified/',
                                              model_type='lstm',
                                              solar_cycle=22,
                                              group_by='output_size',
                                              n_top=2)

# %%
df_lstm
# Out:
#     input_size  output_size  n_hidden  n_layers  num_directions model_type  \
# 0            1            1        20         2               1       lstm
# 1            1            1        20         2               1       lstm
# 2            1            5        20         2               1       lstm
# 3            1            5        20         2               1       lstm
# 4            1           10        20         2               1       lstm
# 5            1           10        20         2               1       lstm
# 6            1            1        30         2               1       lstm
# 7            1            1        30         2               1       lstm
# 8            1            5        30         2               1       lstm
# 9            1            5        30         2               1       lstm
# 10           1           10        30         2               1       lstm
# 11           1           10        30         2               1       lstm
# 12           1            1        40         2               1       lstm
# 13           1            1        40         2               1       lstm
# 14           1            5        40         2               1       lstm
# 15           1            5        40         2               1       lstm
# 16           1           10        40         2               1       lstm
# 17           1           10        40         2               1       lstm
# 18           1            1        50         2               1       lstm
# 19           1            1        50         2               1       lstm
# 20           1            5        50         2               1       lstm
# 21           1            5        50         2               1       lstm
# 22           1           10        50         2               1       lstm
# 23           1           10        50         2               1       lstm
# 24           1            1        60         2               1       lstm
# 25           1            1        60         2               1       lstm
# 26           1            5        60         2               1       lstm
# 27           1            5        60         2               1       lstm
# 28           1           10        60         2               1       lstm
# 29           1           10        60         2               1       lstm
#
#     batch_first     lr device  num_epochs  Validation_Error  Training_Error  \
# 0          True  0.001    cpu        4000          0.059710        0.000081
# 1          True  0.001    cpu        5000          0.075688        0.000082
# 2          True  0.001    cpu        4000          0.030661        0.000448
# 3          True  0.001    cpu        5000          0.062430        0.000397
# 4          True  0.001    cpu        4000          0.072277        0.001119
# 5          True  0.001    cpu        5000          0.042700        0.001006
# 6          True  0.001    cpu        4000          0.036997        0.000080
# 7          True  0.001    cpu        5000          0.042869        0.000080
# 8          True  0.001    cpu        4000          0.027851        0.000390
# 9          True  0.001    cpu        5000          0.028472        0.000370
# 10         True  0.001    cpu        4000          0.078506        0.000818
# 11         True  0.001    cpu        5000          0.109366        0.001058
# 12         True  0.001    cpu        4000          0.050937        0.000080
# 13         True  0.001    cpu        5000          0.077647        0.000080
# 14         True  0.001    cpu        4000          0.032994        0.000340
# 15         True  0.001    cpu        5000          0.052952        0.000330
# 16         True  0.001    cpu        4000          0.061472        0.000727
# 17         True  0.001    cpu        5000          0.111119        0.000395
# 18         True  0.001    cpu        4000          0.067497        0.000079
# 19         True  0.001    cpu        5000          0.049221        0.000081
# 20         True  0.001    cpu        4000          0.028084        0.000345
# 21         True  0.001    cpu        5000          0.028335        0.000310
# 22         True  0.001    cpu        4000          0.104043        0.000328
# 23         True  0.001    cpu        5000          0.039668        0.000276
# 24         True  0.001    cpu        4000          0.066482        0.000080
# 25         True  0.001    cpu        5000          0.054460        0.000080
# 26         True  0.001    cpu        4000          0.042353        0.000321
# 27         True  0.001    cpu        5000          0.029563        0.000302
# 28         True  0.001    cpu        4000          0.038093        0.000469
# 29         True  0.001    cpu        5000          0.143102        0.000178
#
#     Time_Elapsed  Num_Params
# 0    3000.726706        5221
# 1    3759.610790        5221
# 2     699.725517        5305
# 3     876.592338        5305
# 4     426.117630        5410
# 5     533.536996        5410
# 6    3181.618985       11431
# 7    4003.352353       11431
# 8    1060.590307       11555
# 9    1322.672016       11555
# 10    456.188201       11710
# 11    572.256499       11710
# 12   3343.852405       20041
# 13   4182.711939       20041
# 14   1116.352276       20205
# 15   1394.684329       20205
# 16    495.579093       20410
# 17    611.502417       20410
# 18   3595.892863       31051
# 19   4497.290955       31051
# 20   1144.327997       31255
# 21   1430.239305       31255
# 22    518.280028       31510
# 23    646.750577       31510
# 24   3833.719171       44461
# 25   4828.827624       44461
# 26   1109.968830       44705
# 27   1388.312265       44705
# 28    802.028822       45010
# 29   1002.932751       45010

# %%
df_lstm_by_osize
# Out:
#                input_size  output_size  n_hidden  n_layers  num_directions  \
# output_size
# 1           0           1            1        30         2               1
#             1           1            1        30         2               1
# 5           0           1            5        30         2               1
#             1           1            5        50         2               1
# 10          0           1           10        60         2               1
#             1           1           10        50         2               1
#
#               model_type  batch_first     lr device  num_epochs  \
# output_size
# 1           0       lstm         True  0.001    cpu        4000
#             1       lstm         True  0.001    cpu        5000
# 5           0       lstm         True  0.001    cpu        4000
#             1       lstm         True  0.001    cpu        4000
# 10          0       lstm         True  0.001    cpu        4000
#             1       lstm         True  0.001    cpu        5000
#
#                Validation_Error  Training_Error  Time_Elapsed  Num_Params
# output_size
# 1           0          0.036997        0.000080   3181.618985       11431
#             1          0.042869        0.000080   4003.352353       11431
# 5           0          0.027851        0.000390   1060.590307       11555
#             1          0.028084        0.000345   1144.327997       31255
# 10          0          0.038093        0.000469    802.028822       45010
#             1          0.039668        0.000276    646.750577       31510

# %%
df_lstm_by_osize.sort_values(by='Validation_Error',
                            ascending=True, 
                            ignore_index=True)
# Out:
#    input_size  output_size  n_hidden  n_layers  num_directions model_type  \
# 0           1            5        30         2               1       lstm
# 1           1            5        50         2               1       lstm
# 2           1            1        30         2               1       lstm
# 3           1           10        60         2               1       lstm
# 4           1           10        50         2               1       lstm
# 5           1            1        30         2               1       lstm
#
#    batch_first     lr device  num_epochs  Validation_Error  Training_Error  \
# 0         True  0.001    cpu        4000          0.027851        0.000390
# 1         True  0.001    cpu        4000          0.028084        0.000345
# 2         True  0.001    cpu        4000          0.036997        0.000080
# 3         True  0.001    cpu        4000          0.038093        0.000469
# 4         True  0.001    cpu        5000          0.039668        0.000276
# 5         True  0.001    cpu        5000          0.042869        0.000080
#
#    Time_Elapsed  Num_Params
# 0   1060.590307       11555
# 1   1144.327997       31255
# 2   3181.618985       11431
# 3    802.028822       45010
# 4    646.750577       31510
# 5   4003.352353       11431

# %%
df_best_for_gru.iloc[1].to_dict()
# Out:
# {'input_size': 1,
#  'output_size': 5,
#  'n_hidden': 50,
#  'n_layers': 2,
#  'num_directions': 1,
#  'model_type': 'gru',
#  'batch_first': True,
#  'lr': 0.001,
#  'device': 'cpu',
#  'num_epochs': 4000,
#  'Validation_Error': 0.00045996459084500003,
#  'Training_Error': 0.00042754743481000003}
